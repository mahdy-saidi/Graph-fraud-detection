# %%
import torch
from torch_geometric.nn import VGAE, RGCNConv
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
import numpy as np
from pathlib import Path

# %%
def load_graphs(graph_dir):
    # Vérification du dossier
    graph_dir = Path(graph_dir)
    if not graph_dir.exists():
        raise FileNotFoundError(
            f"Le dossier '{graph_dir}' n'existe pas."
        )
    if not graph_dir.is_dir():
        raise NotADirectoryError(
            f"'{graph_dir}' n'est pas un dossier valide."
        )
    graphs = []
    # Charger tous les fichiers .pt
    for file_path in sorted(graph_dir.glob("*.pt")):
        try:
            g = torch.load(file_path)
            graphs.append(g)
            print(f"Graphe chargé : {file_path}")
        except Exception as e:
            print(f"Erreur lors du chargement de {file_path} : {e}")
    return graphs

# Charger les graphes
train_graphs_dir = "graphs/train"
test_graphs_dir = "graphs/test"

train_graphs = load_graphs(train_graphs_dir)
test_graphs = load_graphs(test_graphs_dir)
# Out:
# Graphe chargé : graphs/train/graph_batch_1.pt
# Graphe chargé : graphs/train/graph_batch_10.pt
# Graphe chargé : graphs/train/graph_batch_11.pt
# Graphe chargé : graphs/train/graph_batch_12.pt
# Graphe chargé : graphs/train/graph_batch_2.pt
# Graphe chargé : graphs/train/graph_batch_3.pt
# Graphe chargé : graphs/train/graph_batch_4.pt
# Graphe chargé : graphs/train/graph_batch_5.pt
# Graphe chargé : graphs/train/graph_batch_6.pt
# Graphe chargé : graphs/train/graph_batch_7.pt
# Graphe chargé : graphs/train/graph_batch_8.pt
# Graphe chargé : graphs/train/graph_batch_9.pt
# Graphe chargé : graphs/test/graph_batch_1.pt
# Graphe chargé : graphs/test/graph_batch_2.pt
# Graphe chargé : graphs/test/graph_batch_3.pt
# Graphe chargé : graphs/test/graph_batch_4.pt
# Graphe chargé : graphs/test/graph_batch_5.pt
# Graphe chargé : graphs/test/graph_batch_6.pt
# Graphe chargé : graphs/test/graph_batch_7.pt
# /tmp/ipykernel_65561/3133579107.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   g = torch.load(file_path)

# %% [markdown]
# ## Split temporel (train / val)

# %%
num_graphs = len(train_graphs)

train_ratio = 0.8

train_end = int(train_ratio * num_graphs)

val_graphs   = train_graphs[train_end:]
train_graphs = train_graphs[:train_end]


# Créer un DataLoader pour l'entraînement
# batch_size = nombre de graphes dans chaque batch
batch_size = 1

train_loader = DataLoader(
    train_graphs,
    batch_size=batch_size,
    shuffle=False
)

val_loader = DataLoader(
    val_graphs,
    batch_size=batch_size,
    shuffle=False
)

test_loader = DataLoader(
    test_graphs,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# ## Normalisation des features

# %%
# concaténation de tous les noeuds du TRAIN
xs = torch.cat([g.x for g in train_graphs], dim=0)

mean = xs.mean(dim=0)
std  = xs.std(dim=0, unbiased=False) + 1e-6  # plus stable

def normalize_graph(g, mean, std):
    g = g.clone()
    g.x = (g.x - mean) / std
    return g


train_graphs = [normalize_graph(g, mean, std) for g in train_graphs]
val_graphs   = [normalize_graph(g, mean, std) for g in val_graphs]
test_graphs  = [normalize_graph(g, mean, std) for g in test_graphs]

# %% [markdown]
# ## Définir l’encodeur

# %%
class RGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_relations, dropout=0.3):
        super(RGCNEncoder, self).__init__()
        self.dropout = dropout
        self.conv1 = RGCNConv(in_channels, hidden_channels, num_relations)
        self.conv_mu = RGCNConv(hidden_channels, out_channels, num_relations)
        self.conv_logvar = RGCNConv(hidden_channels, out_channels, num_relations)

    def forward(self, x, edge_index, edge_type):
        x = self.conv1(x, edge_index, edge_type)
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        mu = self.conv_mu(x, edge_index, edge_type)
        logvar = self.conv_logvar(x, edge_index, edge_type)
        return mu, logvar

# %% [markdown]
# ## Créer le modèle VGAE

# %%
in_channels = train_graphs[0].x.size(1)
hidden_channels = 16
out_channels = 8
num_relations = 2  # same_card, same_merchant

encoder = RGCNEncoder(in_channels, hidden_channels, out_channels, num_relations)
model = VGAE(encoder)

# %% [markdown]
# ## Définir l’optimiseur

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr= 5e-4, weight_decay=1e-4)

# %% [markdown]
# ## Détecter le device (GPU si dispo)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Déplacer le modèle
model = model.to(device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Early Stopping

# %%
patience = 50  # nombre d'époques sans amélioration
best_loss = float('inf')
counter = 0

# %% [markdown]
# ## Entraînement du modèle

# %%
num_epochs = 1000
kl_anneal_epochs = 100  # montée progressive de β


for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0.0

    beta = min(1.0, epoch / kl_anneal_epochs)
    
    # ===== ENTRAÎNEMENT SUR LE PASSÉ =====
    for t, data in enumerate(train_loader):
        assert data.edge_index.dtype == torch.long
        assert data.edge_index.min() >= 0
        assert data.edge_index.max() < data.num_nodes
        # Chaque data = 1 graphe temporel
        data = data.to(device)

        optimizer.zero_grad()
        # Encodage VGAE (NNConv utilise edge_attr)
        z = model.encode(
            data.x,
            data.edge_index,
            data.edge_type
        )
        # Loss VGAE = reconstruction + KL
        recon_loss = model.recon_loss(z, data.edge_index) / data.num_nodes  # normalisation
        kl_loss = model.kl_loss() / data.num_nodes  # normalisation
        loss = recon_loss + beta * kl_loss
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # ===== VALIDATION SUR LE FUTUR (SANS BACKPROP) =====
    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for data in val_loader:
            data = data.to(device)

            z = model.encode(
                data.x,
                data.edge_index,
                data.edge_type
            )

            recon_loss = model.recon_loss(z, data.edge_index) / data.num_nodes  # normalisation
            kl_loss = model.kl_loss() / data.num_nodes

            val_loss += (recon_loss + kl_loss).item()

    print(
        f"Epoch {epoch:03d} | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f}"
    )

    # ===== EARLY STOPPING TEMPOREL =====
    if val_loss < best_loss:
        best_loss = val_loss
        counter = 0
        torch.save(model.state_dict(), "best_vgae_rgcn.pt")
    else:
        counter += 1
        if counter >= patience:
            print(f"Early stopping triggered at epoch {epoch}")
            break
# Out:
# Epoch 001 | Train Loss: 17196541.0273 | Val Loss: 1987969.5625
# Epoch 002 | Train Loss: 32207972.0332 | Val Loss: 1881357.0625
# Epoch 003 | Train Loss: 53764960.7627 | Val Loss: 1765784.8125
# Epoch 004 | Train Loss: 69380727.6445 | Val Loss: 1653570.1562
# Epoch 005 | Train Loss: 78830123.0742 | Val Loss: 1543033.1875
# Epoch 006 | Train Loss: 101606232.4551 | Val Loss: 1428879.0625
# Epoch 007 | Train Loss: 100891672.7148 | Val Loss: 1328239.0938
# Epoch 008 | Train Loss: 101384290.8066 | Val Loss: 1234069.9375
# Epoch 009 | Train Loss: 118546027.5898 | Val Loss: 1144210.0000
# Epoch 010 | Train Loss: 139909565.8164 | Val Loss: 1056274.1875
# Epoch 011 | Train Loss: 132145152.9082 | Val Loss: 976533.9375
# Epoch 012 | Train Loss: 135007863.0430 | Val Loss: 901353.3438
# Epoch 013 | Train Loss: 146018357.3848 | Val Loss: 828962.6562
# Epoch 014 | Train Loss: 157453061.2949 | Val Loss: 763906.4531
# Epoch 015 | Train Loss: 156018470.9277 | Val Loss: 702332.4219
# Epoch 016 | Train Loss: 159599166.8887 | Val Loss: 644669.3594
# Epoch 017 | Train Loss: 152919659.2773 | Val Loss: 590860.6719
# Epoch 018 | Train Loss: 170840551.3887 | Val Loss: 540574.4375
# Epoch 019 | Train Loss: 179330061.9395 | Val Loss: 494377.2500
# Epoch 020 | Train Loss: 170869271.3145 | Val Loss: 452961.9219
# Epoch 021 | Train Loss: 160570128.8438 | Val Loss: 415415.2422
# Epoch 022 | Train Loss: 184583264.9863 | Val Loss: 379123.5547
# Epoch 023 | Train Loss: 178949352.5586 | Val Loss: 345975.3984
# Epoch 024 | Train Loss: 182310351.9629 | Val Loss: 316118.8984
# Epoch 025 | Train Loss: 171327966.5566 | Val Loss: 286906.7344
# Epoch 026 | Train Loss: 171432862.3848 | Val Loss: 261318.2109
# Epoch 027 | Train Loss: 181486844.6914 | Val Loss: 238033.1016
# Epoch 028 | Train Loss: 172897815.1016 | Val Loss: 217001.9844
# Epoch 029 | Train Loss: 191790767.7305 | Val Loss: 198467.8164
# Epoch 030 | Train Loss: 149309697.6035 | Val Loss: 180925.0781
# Epoch 031 | Train Loss: 173070147.4180 | Val Loss: 163973.2188
# Epoch 032 | Train Loss: 166405784.6377 | Val Loss: 149428.1523
# Epoch 033 | Train Loss: 164987294.3672 | Val Loss: 136397.7539
# Epoch 034 | Train Loss: 187294989.1377 | Val Loss: 124577.1875
# Epoch 035 | Train Loss: 161160023.8711 | Val Loss: 113817.6914
# Epoch 036 | Train Loss: 166699698.5273 | Val Loss: 103075.4121
# Epoch 037 | Train Loss: 156064044.0273 | Val Loss: 92811.7637
# Epoch 038 | Train Loss: 153835469.3350 | Val Loss: 84056.1484
# Epoch 039 | Train Loss: 163340131.3076 | Val Loss: 76239.1113
# Epoch 040 | Train Loss: 154119420.8760 | Val Loss: 69329.0977
# Epoch 041 | Train Loss: 164029094.6436 | Val Loss: 62610.8398
# Epoch 042 | Train Loss: 162708765.1606 | Val Loss: 56497.4746
# Epoch 043 | Train Loss: 152073429.7461 | Val Loss: 51169.7344
# Epoch 044 | Train Loss: 152974905.1655 | Val Loss: 45860.6807
# Epoch 045 | Train Loss: 160506826.4531 | Val Loss: 41402.5342
# Epoch 046 | Train Loss: 149908604.5425 | Val Loss: 37537.1680
# Epoch 047 | Train Loss: 149975587.5537 | Val Loss: 34186.0498
# Epoch 048 | Train Loss: 149592484.4082 | Val Loss: 31053.3965
# Epoch 049 | Train Loss: 135562421.6484 | Val Loss: 28344.4424
# Epoch 050 | Train Loss: 149315623.9011 | Val Loss: 25798.2378
# Epoch 051 | Train Loss: 136185575.8721 | Val Loss: 23216.9194
# Epoch 052 | Train Loss: 141800041.3665 | Val Loss: 21035.8096
# Epoch 053 | Train Loss: 146969330.0842 | Val Loss: 19425.6655
# Epoch 054 | Train Loss: 144211296.1936 | Val Loss: 17885.3022
# Epoch 055 | Train Loss: 143015279.6055 | Val Loss: 16216.3247
# Epoch 056 | Train Loss: 144493039.9146 | Val Loss: 14848.1265
# Epoch 057 | Train Loss: 130655503.7454 | Val Loss: 13738.5903
# Epoch 058 | Train Loss: 136764842.4692 | Val Loss: 12716.3755
# Epoch 059 | Train Loss: 114610321.4839 | Val Loss: 11917.1243
# Epoch 060 | Train Loss: 119941419.1903 | Val Loss: 11153.8643
# Epoch 061 | Train Loss: 116906831.0393 | Val Loss: 10420.6526
# Epoch 062 | Train Loss: 114481607.5349 | Val Loss: 9715.1838
# Epoch 063 | Train Loss: 118515144.5165 | Val Loss: 9048.4128
# Epoch 064 | Train Loss: 128160508.6824 | Val Loss: 8478.7368
# Epoch 065 | Train Loss: 120069528.4659 | Val Loss: 7888.6604
# Epoch 066 | Train Loss: 116934895.6644 | Val Loss: 7417.6240
# Epoch 067 | Train Loss: 132346336.7858 | Val Loss: 7010.4348
# Epoch 068 | Train Loss: 113676500.7635 | Val Loss: 6630.7030
# Epoch 069 | Train Loss: 118942582.3879 | Val Loss: 6298.3931
# Epoch 070 | Train Loss: 109420738.6295 | Val Loss: 5875.1616
# Epoch 071 | Train Loss: 106248345.6136 | Val Loss: 5517.0341
# Epoch 072 | Train Loss: 122723467.4896 | Val Loss: 5284.9834
# Epoch 073 | Train Loss: 105469482.6880 | Val Loss: 4948.5846
# Epoch 074 | Train Loss: 107439340.1406 | Val Loss: 4684.5321
# Epoch 075 | Train Loss: 109538029.5178 | Val Loss: 4454.9264
# Epoch 076 | Train Loss: 96219085.1572 | Val Loss: 4205.1890
# Epoch 077 | Train Loss: 106575438.0533 | Val Loss: 4048.3999
# Epoch 078 | Train Loss: 85959497.7664 | Val Loss: 3804.6425
# Epoch 079 | Train Loss: 94248852.9978 | Val Loss: 3611.0381
# Epoch 080 | Train Loss: 98207194.0061 | Val Loss: 3441.8214
# Epoch 081 | Train Loss: 104977305.8293 | Val Loss: 3212.3002
# Epoch 082 | Train Loss: 98216133.2870 | Val Loss: 2985.5709
# Epoch 083 | Train Loss: 89397516.9017 | Val Loss: 2882.4933
# Epoch 084 | Train Loss: 84985066.5020 | Val Loss: 2745.4274
# Epoch 085 | Train Loss: 91547103.0167 | Val Loss: 2627.9557
# Epoch 086 | Train Loss: 92654721.4456 | Val Loss: 2515.7837
# Epoch 087 | Train Loss: 89050602.7131 | Val Loss: 2399.4370
# Epoch 088 | Train Loss: 84804774.6454 | Val Loss: 2303.4360
# Epoch 089 | Train Loss: 77698051.3085 | Val Loss: 2228.4245
# Epoch 090 | Train Loss: 84498930.8275 | Val Loss: 2157.5378
# Epoch 091 | Train Loss: 82661272.2542 | Val Loss: 2096.4843
# Epoch 092 | Train Loss: 86632939.1531 | Val Loss: 2007.1597
# Epoch 093 | Train Loss: 72753494.8333 | Val Loss: 1934.8408
# Epoch 094 | Train Loss: 80770499.9355 | Val Loss: 1857.1116
# Epoch 095 | Train Loss: 80470634.7787 | Val Loss: 1779.7106
# Epoch 096 | Train Loss: 85715862.5631 | Val Loss: 1718.8598
# Epoch 097 | Train Loss: 72166363.8935 | Val Loss: 1669.4928
# Epoch 098 | Train Loss: 75338283.7967 | Val Loss: 1608.5278
# Epoch 099 | Train Loss: 67401595.7860 | Val Loss: 1544.1088
# Epoch 100 | Train Loss: 78310732.3964 | Val Loss: 1482.5409
# Epoch 101 | Train Loss: 66400820.9817 | Val Loss: 1422.5268
# Epoch 102 | Train Loss: 62247180.5954 | Val Loss: 1362.9099
# Epoch 103 | Train Loss: 67098430.2539 | Val Loss: 1312.3954
# Epoch 104 | Train Loss: 65756368.8891 | Val Loss: 1256.5037
# Epoch 105 | Train Loss: 56551594.9345 | Val Loss: 1203.0903
# Epoch 106 | Train Loss: 61364157.1879 | Val Loss: 1156.8049
# Epoch 107 | Train Loss: 67157403.1474 | Val Loss: 1107.0934
# Epoch 108 | Train Loss: 68997382.7384 | Val Loss: 1064.5226
# Epoch 109 | Train Loss: 69353470.7231 | Val Loss: 1029.3419
# Epoch 110 | Train Loss: 61601129.6140 | Val Loss: 987.9926
# Epoch 111 | Train Loss: 54078396.2534 | Val Loss: 952.2259
# Epoch 112 | Train Loss: 55938686.8847 | Val Loss: 923.2942
# Epoch 113 | Train Loss: 58959389.8043 | Val Loss: 899.0256
# Epoch 114 | Train Loss: 51538157.6879 | Val Loss: 873.9013
# Epoch 115 | Train Loss: 49945714.8628 | Val Loss: 852.5709
# Epoch 116 | Train Loss: 44955659.3357 | Val Loss: 831.9740
# Epoch 117 | Train Loss: 43217996.9478 | Val Loss: 814.6953
# Epoch 118 | Train Loss: 54297744.8888 | Val Loss: 794.2983
# Epoch 119 | Train Loss: 40825723.3815 | Val Loss: 774.6445
# Epoch 120 | Train Loss: 43171649.1692 | Val Loss: 754.2434
# Epoch 121 | Train Loss: 37394356.1229 | Val Loss: 737.2246
# Epoch 122 | Train Loss: 44829731.8958 | Val Loss: 722.3770
# Epoch 123 | Train Loss: 42400367.3982 | Val Loss: 706.9279
# Epoch 124 | Train Loss: 46286140.9494 | Val Loss: 690.2283
# Epoch 125 | Train Loss: 43566210.9378 | Val Loss: 676.5249
# Epoch 126 | Train Loss: 44793600.1243 | Val Loss: 662.8230
# Epoch 127 | Train Loss: 38022551.8721 | Val Loss: 649.5443
# Epoch 128 | Train Loss: 38023530.4804 | Val Loss: 635.6561
# Epoch 129 | Train Loss: 38087425.3254 | Val Loss: 619.9085
# Epoch 130 | Train Loss: 39574081.8231 | Val Loss: 606.1958
# Epoch 131 | Train Loss: 42045083.0158 | Val Loss: 592.3092
# Epoch 132 | Train Loss: 38109065.5213 | Val Loss: 579.7331
# Epoch 133 | Train Loss: 42349723.2237 | Val Loss: 566.5247
# Epoch 134 | Train Loss: 38644933.5278 | Val Loss: 551.6433
# Epoch 135 | Train Loss: 31600175.8034 | Val Loss: 539.8602
# Epoch 136 | Train Loss: 33195915.2194 | Val Loss: 532.2511
# Epoch 137 | Train Loss: 30578636.9188 | Val Loss: 524.4172
# Epoch 138 | Train Loss: 33690978.8320 | Val Loss: 515.7922
# Epoch 139 | Train Loss: 29859181.1127 | Val Loss: 504.0003
# Epoch 140 | Train Loss: 26334419.1069 | Val Loss: 493.4319
# Epoch 141 | Train Loss: 27502866.5739 | Val Loss: 485.7484
# Epoch 142 | Train Loss: 30753888.5590 | Val Loss: 478.2512
# Epoch 143 | Train Loss: 29904802.4263 | Val Loss: 472.8808
# Epoch 144 | Train Loss: 29282409.9362 | Val Loss: 467.2790
# Epoch 145 | Train Loss: 27826293.7850 | Val Loss: 461.6485
# Epoch 146 | Train Loss: 26657991.8032 | Val Loss: 456.4432
# Epoch 147 | Train Loss: 27685359.2402 | Val Loss: 450.2713
# Epoch 148 | Train Loss: 29427036.0913 | Val Loss: 442.5840
# Epoch 149 | Train Loss: 27602286.8357 | Val Loss: 435.0789
# Epoch 150 | Train Loss: 23374182.1212 | Val Loss: 427.3542
# Epoch 151 | Train Loss: 23917781.9240 | Val Loss: 421.5834
# Epoch 152 | Train Loss: 27860962.7134 | Val Loss: 415.6068
# Epoch 153 | Train Loss: 26077672.2599 | Val Loss: 410.2032
# Epoch 154 | Train Loss: 23151320.6930 | Val Loss: 405.1808
# Epoch 155 | Train Loss: 20776694.2593 | Val Loss: 400.2422
# Epoch 156 | Train Loss: 25016258.6912 | Val Loss: 396.0410
# Epoch 157 | Train Loss: 18988832.9936 | Val Loss: 389.9699
# Epoch 158 | Train Loss: 21602193.5629 | Val Loss: 385.4002
# Epoch 159 | Train Loss: 19248425.6971 | Val Loss: 379.2561
# Epoch 160 | Train Loss: 23835925.1923 | Val Loss: 374.3178
# Epoch 161 | Train Loss: 24646281.6584 | Val Loss: 369.4684
# Epoch 162 | Train Loss: 21397782.6989 | Val Loss: 365.5295
# Epoch 163 | Train Loss: 20800236.1367 | Val Loss: 361.4162
# Epoch 164 | Train Loss: 17989160.4637 | Val Loss: 357.6014
# Epoch 165 | Train Loss: 20133229.3278 | Val Loss: 353.1046
# Epoch 166 | Train Loss: 18446211.4683 | Val Loss: 349.0582
# Epoch 167 | Train Loss: 16626821.2153 | Val Loss: 344.7714
# Epoch 168 | Train Loss: 18351240.1392 | Val Loss: 339.2539
# Epoch 169 | Train Loss: 16750067.8809 | Val Loss: 334.7988
# Epoch 170 | Train Loss: 18110829.7347 | Val Loss: 329.6134
# Epoch 171 | Train Loss: 21010741.7475 | Val Loss: 323.9598
# Epoch 172 | Train Loss: 19533523.4483 | Val Loss: 319.8941
# Epoch 173 | Train Loss: 18417915.7749 | Val Loss: 317.4990
# Epoch 174 | Train Loss: 15949775.3109 | Val Loss: 314.5266
# Epoch 175 | Train Loss: 17991891.7549 | Val Loss: 311.5825
# Epoch 176 | Train Loss: 18940718.3374 | Val Loss: 306.3301
# Epoch 177 | Train Loss: 19597592.6747 | Val Loss: 302.8780
# Epoch 178 | Train Loss: 17626389.3527 | Val Loss: 299.3074
# Epoch 179 | Train Loss: 19688452.5580 | Val Loss: 295.5778
# Epoch 180 | Train Loss: 15150887.1127 | Val Loss: 291.7745
# Epoch 181 | Train Loss: 15245655.9901 | Val Loss: 288.2985
# Epoch 182 | Train Loss: 12573320.2274 | Val Loss: 285.2411
# Epoch 183 | Train Loss: 15680892.9098 | Val Loss: 282.0734
# Epoch 184 | Train Loss: 14775512.1185 | Val Loss: 277.9311
# Epoch 185 | Train Loss: 13307650.1687 | Val Loss: 274.6014
# Epoch 186 | Train Loss: 12979955.2033 | Val Loss: 272.1264
# Epoch 187 | Train Loss: 16002448.7884 | Val Loss: 269.8973
# Epoch 188 | Train Loss: 16461278.5087 | Val Loss: 266.0834
# Epoch 189 | Train Loss: 13202115.1278 | Val Loss: 263.2467
# Epoch 190 | Train Loss: 14392481.5010 | Val Loss: 261.2717
# Epoch 191 | Train Loss: 13174690.8061 | Val Loss: 259.3615
# Epoch 192 | Train Loss: 12802865.1062 | Val Loss: 256.9799
# Epoch 193 | Train Loss: 10448494.5567 | Val Loss: 255.8073
# Epoch 194 | Train Loss: 10841569.5335 | Val Loss: 253.9958
# Epoch 195 | Train Loss: 12881742.3568 | Val Loss: 252.5056
# Epoch 196 | Train Loss: 13519908.9515 | Val Loss: 249.3337
# Epoch 197 | Train Loss: 15006892.1249 | Val Loss: 247.5625
# Epoch 198 | Train Loss: 12432949.7894 | Val Loss: 245.9611
# Epoch 199 | Train Loss: 9758423.6884 | Val Loss: 242.4718
# Epoch 200 | Train Loss: 10473825.2394 | Val Loss: 240.2761
# Epoch 201 | Train Loss: 8541935.9800 | Val Loss: 238.0282
# Epoch 202 | Train Loss: 10844655.2797 | Val Loss: 234.3099
# Epoch 203 | Train Loss: 11049543.2054 | Val Loss: 230.4116
# Epoch 204 | Train Loss: 10134351.8435 | Val Loss: 228.6742
# Epoch 205 | Train Loss: 8957225.9918 | Val Loss: 227.2500
# Epoch 206 | Train Loss: 10214691.0384 | Val Loss: 225.6693
# Epoch 207 | Train Loss: 9982673.3403 | Val Loss: 223.7622
# Epoch 208 | Train Loss: 9499459.7999 | Val Loss: 219.8615
# Epoch 209 | Train Loss: 9187949.7613 | Val Loss: 217.6586
# Epoch 210 | Train Loss: 11213265.6362 | Val Loss: 216.1649
# Epoch 211 | Train Loss: 8689557.3076 | Val Loss: 213.5498
# Epoch 212 | Train Loss: 8597323.5492 | Val Loss: 211.0848
# Epoch 213 | Train Loss: 10129094.6482 | Val Loss: 208.5126
# Epoch 214 | Train Loss: 7979008.2752 | Val Loss: 206.0953
# Epoch 215 | Train Loss: 8525735.1669 | Val Loss: 204.9000
# Epoch 216 | Train Loss: 7830897.9806 | Val Loss: 203.6722
# Epoch 217 | Train Loss: 8862575.9808 | Val Loss: 201.5394
# Epoch 218 | Train Loss: 7986128.0466 | Val Loss: 200.1052
# Epoch 219 | Train Loss: 7929215.1981 | Val Loss: 198.8875
# Epoch 220 | Train Loss: 8926643.1013 | Val Loss: 197.2311
# Epoch 221 | Train Loss: 6907693.9798 | Val Loss: 194.8897
# Epoch 222 | Train Loss: 7465065.9129 | Val Loss: 192.3473
# Epoch 223 | Train Loss: 6591224.2694 | Val Loss: 189.3405
# Epoch 224 | Train Loss: 7492631.4352 | Val Loss: 187.7329
# Epoch 225 | Train Loss: 6894117.3296 | Val Loss: 186.0211
# Epoch 226 | Train Loss: 7255101.4905 | Val Loss: 182.0435
# Epoch 227 | Train Loss: 8944466.3818 | Val Loss: 177.6512
# Epoch 228 | Train Loss: 6843519.6925 | Val Loss: 174.8193
# Epoch 229 | Train Loss: 7325098.5367 | Val Loss: 172.8853
# Epoch 230 | Train Loss: 8000933.3880 | Val Loss: 171.1539
# Epoch 231 | Train Loss: 6899477.2459 | Val Loss: 168.9657
# Epoch 232 | Train Loss: 6813207.4938 | Val Loss: 167.5374
# Epoch 233 | Train Loss: 5841945.5129 | Val Loss: 165.7258
# Epoch 234 | Train Loss: 7379940.7149 | Val Loss: 162.5294
# Epoch 235 | Train Loss: 5558580.7423 | Val Loss: 161.7331
# Epoch 236 | Train Loss: 6040511.3100 | Val Loss: 160.4519
# Epoch 237 | Train Loss: 5894908.1355 | Val Loss: 158.5304
# Epoch 238 | Train Loss: 4809643.0372 | Val Loss: 157.0773
# Epoch 239 | Train Loss: 5755301.6515 | Val Loss: 155.3360
# Epoch 240 | Train Loss: 6034860.5574 | Val Loss: 154.2464
# Epoch 241 | Train Loss: 5064396.4060 | Val Loss: 153.9967
# Epoch 242 | Train Loss: 6577719.4316 | Val Loss: 152.2772
# Epoch 243 | Train Loss: 4889195.7082 | Val Loss: 149.0256
# Epoch 244 | Train Loss: 6302603.5285 | Val Loss: 148.2841
# Epoch 245 | Train Loss: 6284803.7982 | Val Loss: 148.0350
# Epoch 246 | Train Loss: 5648979.2891 | Val Loss: 147.3979
# Epoch 247 | Train Loss: 5813946.6140 | Val Loss: 146.8893
# Epoch 248 | Train Loss: 5205484.9998 | Val Loss: 146.1473
# Epoch 249 | Train Loss: 4673386.6315 | Val Loss: 144.0183
# Epoch 250 | Train Loss: 4689984.6198 | Val Loss: 142.4651
# Epoch 251 | Train Loss: 4023377.9714 | Val Loss: 142.0943
# Epoch 252 | Train Loss: 4243682.1954 | Val Loss: 142.1164
# Epoch 253 | Train Loss: 4681028.3432 | Val Loss: 141.8498
# Epoch 254 | Train Loss: 4279078.5661 | Val Loss: 141.0226
# Epoch 255 | Train Loss: 5047213.7910 | Val Loss: 139.2355
# Epoch 256 | Train Loss: 3648101.4149 | Val Loss: 137.9564
# Epoch 257 | Train Loss: 5072222.5027 | Val Loss: 135.8129
# Epoch 258 | Train Loss: 4579927.2598 | Val Loss: 134.4200
# Epoch 259 | Train Loss: 4005649.9901 | Val Loss: 133.3367
# Epoch 260 | Train Loss: 3812937.3284 | Val Loss: 131.8524
# Epoch 261 | Train Loss: 4132959.8464 | Val Loss: 130.9136
# Epoch 262 | Train Loss: 4154262.7591 | Val Loss: 130.3272
# Epoch 263 | Train Loss: 3841724.7815 | Val Loss: 128.6636
# Epoch 264 | Train Loss: 3200991.6074 | Val Loss: 127.4386
# Epoch 265 | Train Loss: 4429094.4841 | Val Loss: 125.6013
# Epoch 266 | Train Loss: 4246144.6669 | Val Loss: 124.4977
# Epoch 267 | Train Loss: 3774629.6279 | Val Loss: 121.8028
# Epoch 268 | Train Loss: 4528063.3514 | Val Loss: 119.6680
# Epoch 269 | Train Loss: 3131540.2449 | Val Loss: 117.4194
# Epoch 270 | Train Loss: 4327720.5362 | Val Loss: 115.2545
# Epoch 271 | Train Loss: 3061800.5887 | Val Loss: 114.5344
# Epoch 272 | Train Loss: 3842357.4565 | Val Loss: 114.4262
# Epoch 273 | Train Loss: 2867739.4320 | Val Loss: 113.4525
# Epoch 274 | Train Loss: 3311340.1539 | Val Loss: 111.9565
# Epoch 275 | Train Loss: 2770186.0559 | Val Loss: 108.8211
# Epoch 276 | Train Loss: 3173590.7621 | Val Loss: 106.9688
# Epoch 277 | Train Loss: 3434675.7804 | Val Loss: 105.6752
# Epoch 278 | Train Loss: 3621278.3501 | Val Loss: 103.0026
# Epoch 279 | Train Loss: 3215853.6300 | Val Loss: 102.1510
# Epoch 280 | Train Loss: 4200915.4950 | Val Loss: 100.1915
# Epoch 281 | Train Loss: 3989031.9927 | Val Loss: 99.1566
# Epoch 282 | Train Loss: 2617936.0176 | Val Loss: 98.6910
# Epoch 283 | Train Loss: 2638474.1358 | Val Loss: 97.3634
# Epoch 284 | Train Loss: 2334715.3309 | Val Loss: 95.8331
# Epoch 285 | Train Loss: 2668570.6399 | Val Loss: 94.9371
# Epoch 286 | Train Loss: 3148682.7503 | Val Loss: 94.3287
# Epoch 287 | Train Loss: 2247245.5505 | Val Loss: 94.0030
# Epoch 288 | Train Loss: 2326495.8436 | Val Loss: 93.1419
# Epoch 289 | Train Loss: 2484491.6157 | Val Loss: 92.1092
# Epoch 290 | Train Loss: 2283404.3044 | Val Loss: 91.9817
# Epoch 291 | Train Loss: 3208457.7823 | Val Loss: 88.6120
# Epoch 292 | Train Loss: 3033685.2120 | Val Loss: 86.3732
# Epoch 293 | Train Loss: 2643548.1065 | Val Loss: 84.2487
# Epoch 294 | Train Loss: 2920784.9913 | Val Loss: 82.8956
# Epoch 295 | Train Loss: 2306459.8431 | Val Loss: 81.5955
# Epoch 296 | Train Loss: 2723908.5991 | Val Loss: 81.4451
# Epoch 297 | Train Loss: 2627983.4260 | Val Loss: 80.9218
# Epoch 298 | Train Loss: 2634148.4081 | Val Loss: 80.6909
# Epoch 299 | Train Loss: 2804165.5190 | Val Loss: 80.5253
# Epoch 300 | Train Loss: 1997945.4667 | Val Loss: 80.1956
# Epoch 301 | Train Loss: 2034221.3049 | Val Loss: 79.7404
# Epoch 302 | Train Loss: 2012224.2023 | Val Loss: 78.4076
# Epoch 303 | Train Loss: 1801877.9648 | Val Loss: 76.9774
# Epoch 304 | Train Loss: 2254609.2049 | Val Loss: 75.6711
# Epoch 305 | Train Loss: 1895643.3454 | Val Loss: 74.4642
# Epoch 306 | Train Loss: 2873320.3737 | Val Loss: 74.2991
# Epoch 307 | Train Loss: 1780514.2420 | Val Loss: 74.4363
# Epoch 308 | Train Loss: 1657367.6304 | Val Loss: 74.2299
# Epoch 309 | Train Loss: 2350558.0523 | Val Loss: 73.4034
# Epoch 310 | Train Loss: 2877543.2905 | Val Loss: 72.4399
# Epoch 311 | Train Loss: 1765462.9716 | Val Loss: 71.8973
# Epoch 312 | Train Loss: 1389561.3291 | Val Loss: 71.7597
# Epoch 313 | Train Loss: 2251923.0443 | Val Loss: 71.3967
# Epoch 314 | Train Loss: 1957106.6290 | Val Loss: 71.0598
# Epoch 315 | Train Loss: 1341679.8844 | Val Loss: 70.7515
# Epoch 316 | Train Loss: 1741866.6938 | Val Loss: 69.4453
# Epoch 317 | Train Loss: 1968956.7605 | Val Loss: 68.9991
# Epoch 318 | Train Loss: 2261524.4173 | Val Loss: 68.5127
# Epoch 319 | Train Loss: 2140471.4186 | Val Loss: 68.2217
# Epoch 320 | Train Loss: 1769885.6045 | Val Loss: 67.6836
# Epoch 321 | Train Loss: 1865320.5522 | Val Loss: 66.6997
# Epoch 322 | Train Loss: 1401332.6646 | Val Loss: 66.5870
# Epoch 323 | Train Loss: 1188384.9907 | Val Loss: 65.1943
# Epoch 324 | Train Loss: 1456559.1923 | Val Loss: 64.2467
# Epoch 325 | Train Loss: 1808303.3878 | Val Loss: 63.7665
# Epoch 326 | Train Loss: 1264820.1943 | Val Loss: 63.0053
# Epoch 327 | Train Loss: 1361572.2461 | Val Loss: 62.4821
# Epoch 328 | Train Loss: 1144817.7945 | Val Loss: 61.9185
# Epoch 329 | Train Loss: 1365385.5315 | Val Loss: 60.7256
# Epoch 330 | Train Loss: 1790045.6464 | Val Loss: 58.7836
# Epoch 331 | Train Loss: 1635021.2823 | Val Loss: 58.7636
# Epoch 332 | Train Loss: 1179322.0530 | Val Loss: 58.3728
# Epoch 333 | Train Loss: 1128220.1016 | Val Loss: 57.8074
# Epoch 334 | Train Loss: 1915630.0320 | Val Loss: 55.6554
# Epoch 335 | Train Loss: 1932343.3261 | Val Loss: 54.7063
# Epoch 336 | Train Loss: 1363992.5693 | Val Loss: 53.6601
# Epoch 337 | Train Loss: 1500602.4588 | Val Loss: 51.7824
# Epoch 338 | Train Loss: 1259050.8438 | Val Loss: 51.4309
# Epoch 339 | Train Loss: 1478736.9366 | Val Loss: 50.5670
# Epoch 340 | Train Loss: 1446047.4719 | Val Loss: 50.4074
# Epoch 341 | Train Loss: 1262178.5349 | Val Loss: 50.3165
# Epoch 342 | Train Loss: 1608257.5341 | Val Loss: 49.7760
# Epoch 343 | Train Loss: 1588509.8740 | Val Loss: 49.1585
# Epoch 344 | Train Loss: 1526651.2072 | Val Loss: 48.9318
# Epoch 345 | Train Loss: 985628.6144 | Val Loss: 48.4417
# Epoch 346 | Train Loss: 1275087.0154 | Val Loss: 48.0631
# Epoch 347 | Train Loss: 1052527.1646 | Val Loss: 47.3987
# Epoch 348 | Train Loss: 974945.3602 | Val Loss: 46.5957
# Epoch 349 | Train Loss: 1308994.8384 | Val Loss: 44.3452
# Epoch 350 | Train Loss: 759396.0861 | Val Loss: 43.5865
# Epoch 351 | Train Loss: 998819.7022 | Val Loss: 42.3535
# Epoch 352 | Train Loss: 825706.7327 | Val Loss: 40.7705
# Epoch 353 | Train Loss: 1030382.7698 | Val Loss: 40.3785
# Epoch 354 | Train Loss: 994479.8706 | Val Loss: 39.3878
# Epoch 355 | Train Loss: 1110043.7056 | Val Loss: 37.9202
# Epoch 356 | Train Loss: 877837.7540 | Val Loss: 37.5430
# Epoch 357 | Train Loss: 934525.7074 | Val Loss: 36.6764
# Epoch 358 | Train Loss: 913022.7647 | Val Loss: 35.4206
# Epoch 359 | Train Loss: 662215.0135 | Val Loss: 35.3024
# Epoch 360 | Train Loss: 1408540.5871 | Val Loss: 35.3505
# Epoch 361 | Train Loss: 733771.8470 | Val Loss: 35.1525
# Epoch 362 | Train Loss: 794082.6378 | Val Loss: 35.0339
# Epoch 363 | Train Loss: 768136.3004 | Val Loss: 36.1159
# Epoch 364 | Train Loss: 643592.0363 | Val Loss: 34.7911
# Epoch 365 | Train Loss: 939156.6925 | Val Loss: 34.5346
# Epoch 366 | Train Loss: 689472.3489 | Val Loss: 33.9651
# Epoch 367 | Train Loss: 770691.4122 | Val Loss: 31.9151
# Epoch 368 | Train Loss: 750033.5575 | Val Loss: 29.7909
# Epoch 369 | Train Loss: 694517.9440 | Val Loss: 28.7465
# Epoch 370 | Train Loss: 660298.3140 | Val Loss: 28.5298
# Epoch 371 | Train Loss: 950995.2614 | Val Loss: 27.6812
# Epoch 372 | Train Loss: 973959.2740 | Val Loss: 26.8644
# Epoch 373 | Train Loss: 856835.1403 | Val Loss: 26.3438
# Epoch 374 | Train Loss: 577312.1489 | Val Loss: 23.6110
# Epoch 375 | Train Loss: 492851.2667 | Val Loss: 23.2104
# Epoch 376 | Train Loss: 960835.7654 | Val Loss: 22.8404
# Epoch 377 | Train Loss: 594123.0229 | Val Loss: 22.2389
# Epoch 378 | Train Loss: 811413.7688 | Val Loss: 21.2080
# Epoch 379 | Train Loss: 931750.0693 | Val Loss: 21.5303
# Epoch 380 | Train Loss: 535192.3794 | Val Loss: 20.8475
# Epoch 381 | Train Loss: 874745.7876 | Val Loss: 20.8221
# Epoch 382 | Train Loss: 954396.6184 | Val Loss: 20.1920
# Epoch 383 | Train Loss: 511412.2777 | Val Loss: 20.5583
# Epoch 384 | Train Loss: 559686.9003 | Val Loss: 22.3665
# Epoch 385 | Train Loss: 661567.5577 | Val Loss: 20.4279
# Epoch 386 | Train Loss: 704830.3487 | Val Loss: 19.1642
# Epoch 387 | Train Loss: 566341.5650 | Val Loss: 18.7368
# Epoch 388 | Train Loss: 684260.6055 | Val Loss: 18.3292
# Epoch 389 | Train Loss: 820419.2791 | Val Loss: 18.8611
# Epoch 390 | Train Loss: 548148.4343 | Val Loss: 18.4708
# Epoch 391 | Train Loss: 511280.0690 | Val Loss: 18.3534
# Epoch 392 | Train Loss: 541441.2906 | Val Loss: 17.5193
# Epoch 393 | Train Loss: 732556.3130 | Val Loss: 17.7770
# Epoch 394 | Train Loss: 483488.5790 | Val Loss: 17.7406
# Epoch 395 | Train Loss: 651042.1049 | Val Loss: 17.3440
# Epoch 396 | Train Loss: 638140.8846 | Val Loss: 17.5259
# Epoch 397 | Train Loss: 411645.6312 | Val Loss: 16.7621
# Epoch 398 | Train Loss: 415750.8818 | Val Loss: 15.8126
# Epoch 399 | Train Loss: 729268.0732 | Val Loss: 14.9778
# Epoch 400 | Train Loss: 443436.4625 | Val Loss: 15.0662
# Epoch 401 | Train Loss: 640348.7699 | Val Loss: 14.2931
# Epoch 402 | Train Loss: 554471.8805 | Val Loss: 14.2489
# Epoch 403 | Train Loss: 543344.0516 | Val Loss: 13.7864
# Epoch 404 | Train Loss: 334292.2991 | Val Loss: 12.0132
# Epoch 405 | Train Loss: 330340.5094 | Val Loss: 11.8808
# Epoch 406 | Train Loss: 695864.8590 | Val Loss: 12.6291
# Epoch 407 | Train Loss: 426616.2538 | Val Loss: 12.8298
# Epoch 408 | Train Loss: 717683.6709 | Val Loss: 12.0025
# Epoch 409 | Train Loss: 409245.2572 | Val Loss: 11.2640
# Epoch 410 | Train Loss: 360719.1457 | Val Loss: 10.4886
# Epoch 411 | Train Loss: 541980.1792 | Val Loss: 10.1971
# Epoch 412 | Train Loss: 487398.7609 | Val Loss: 9.8946
# Epoch 413 | Train Loss: 268814.8904 | Val Loss: 8.5680
# Epoch 414 | Train Loss: 448166.5789 | Val Loss: 8.0935
# Epoch 415 | Train Loss: 350539.6938 | Val Loss: 7.3666
# Epoch 416 | Train Loss: 314512.9511 | Val Loss: 7.3569
# Epoch 417 | Train Loss: 448324.2670 | Val Loss: 7.2632
# Epoch 418 | Train Loss: 317915.0124 | Val Loss: 7.2202
# Epoch 419 | Train Loss: 508569.1498 | Val Loss: 7.1724
# Epoch 420 | Train Loss: 237416.7851 | Val Loss: 7.1699
# Epoch 421 | Train Loss: 286992.5409 | Val Loss: 7.2243
# Epoch 422 | Train Loss: 397152.2584 | Val Loss: 7.2643
# Epoch 423 | Train Loss: 423138.1880 | Val Loss: 7.2707
# Epoch 424 | Train Loss: 452576.3807 | Val Loss: 7.1473
# Epoch 425 | Train Loss: 326295.1851 | Val Loss: 7.0987
# Epoch 426 | Train Loss: 455382.3612 | Val Loss: 6.9800
# Epoch 427 | Train Loss: 294716.4503 | Val Loss: 6.8881
# Epoch 428 | Train Loss: 335665.1326 | Val Loss: 6.8376
# Epoch 429 | Train Loss: 374126.0760 | Val Loss: 6.7873
# Epoch 430 | Train Loss: 421224.9592 | Val Loss: 6.5922
# Epoch 431 | Train Loss: 221946.0051 | Val Loss: 6.3212
# Epoch 432 | Train Loss: 235343.0327 | Val Loss: 6.2718
# Epoch 433 | Train Loss: 436622.6850 | Val Loss: 6.2539
# Epoch 434 | Train Loss: 208719.1910 | Val Loss: 5.8058
# Epoch 435 | Train Loss: 339581.7684 | Val Loss: 5.7482
# Epoch 436 | Train Loss: 295971.4450 | Val Loss: 5.5507
# Epoch 437 | Train Loss: 242177.8701 | Val Loss: 5.3497
# Epoch 438 | Train Loss: 302329.9283 | Val Loss: 5.2952
# Epoch 439 | Train Loss: 171935.1791 | Val Loss: 5.2036
# Epoch 440 | Train Loss: 216681.9592 | Val Loss: 5.1593
# Epoch 441 | Train Loss: 224296.9829 | Val Loss: 5.8764
# Epoch 442 | Train Loss: 203115.2232 | Val Loss: 5.0931
# Epoch 443 | Train Loss: 356408.3362 | Val Loss: 4.9221
# Epoch 444 | Train Loss: 214372.9858 | Val Loss: 4.6900
# Epoch 445 | Train Loss: 157870.3318 | Val Loss: 4.3538
# Epoch 446 | Train Loss: 371006.2145 | Val Loss: 4.3316
# Epoch 447 | Train Loss: 180566.3821 | Val Loss: 4.2870
# Epoch 448 | Train Loss: 320001.3697 | Val Loss: 4.5880
# Epoch 449 | Train Loss: 158589.1455 | Val Loss: 4.5110
# Epoch 450 | Train Loss: 170532.6842 | Val Loss: 4.4512
# Epoch 451 | Train Loss: 226728.2181 | Val Loss: 4.3950
# Epoch 452 | Train Loss: 205226.3989 | Val Loss: 4.3506
# Epoch 453 | Train Loss: 215018.7583 | Val Loss: 4.3272
# Epoch 454 | Train Loss: 341248.6708 | Val Loss: 4.3901
# Epoch 455 | Train Loss: 411920.3414 | Val Loss: 4.4438
# Epoch 456 | Train Loss: 337890.3056 | Val Loss: 4.4995
# Epoch 457 | Train Loss: 293067.2127 | Val Loss: 4.6103
# Epoch 458 | Train Loss: 196203.1873 | Val Loss: 4.5695
# Epoch 459 | Train Loss: 207279.2527 | Val Loss: 4.5085
# Epoch 460 | Train Loss: 178470.8312 | Val Loss: 4.5226
# Epoch 461 | Train Loss: 274798.0663 | Val Loss: 4.5214
# Epoch 462 | Train Loss: 237727.5356 | Val Loss: 4.5084
# Epoch 463 | Train Loss: 142794.0857 | Val Loss: 4.4261
# Epoch 464 | Train Loss: 159229.8184 | Val Loss: 4.3469
# Epoch 465 | Train Loss: 236318.8208 | Val Loss: 4.2459
# Epoch 466 | Train Loss: 193026.0133 | Val Loss: 4.2160
# Epoch 467 | Train Loss: 224113.2152 | Val Loss: 4.2010
# Epoch 468 | Train Loss: 210140.0547 | Val Loss: 4.1815
# Epoch 469 | Train Loss: 171380.0589 | Val Loss: 4.1173
# Epoch 470 | Train Loss: 125413.9160 | Val Loss: 4.1253
# Epoch 471 | Train Loss: 106777.3751 | Val Loss: 4.0674
# Epoch 472 | Train Loss: 198130.0937 | Val Loss: 3.9819
# Epoch 473 | Train Loss: 199970.2371 | Val Loss: 3.9455
# Epoch 474 | Train Loss: 143642.4450 | Val Loss: 3.8440
# Epoch 475 | Train Loss: 201878.2251 | Val Loss: 3.5342
# Epoch 476 | Train Loss: 159189.3152 | Val Loss: 3.2553
# Epoch 477 | Train Loss: 163193.2639 | Val Loss: 3.2932
# Epoch 478 | Train Loss: 218501.3588 | Val Loss: 3.2883
# Epoch 479 | Train Loss: 160311.0128 | Val Loss: 3.2789
# Epoch 480 | Train Loss: 103971.2366 | Val Loss: 3.2655
# Epoch 481 | Train Loss: 126603.0719 | Val Loss: 3.1870
# Epoch 482 | Train Loss: 162581.4286 | Val Loss: 3.1984
# Epoch 483 | Train Loss: 83558.6783 | Val Loss: 3.1436
# Epoch 484 | Train Loss: 80083.3338 | Val Loss: 3.1336
# Epoch 485 | Train Loss: 171775.2323 | Val Loss: 3.1083
# Epoch 486 | Train Loss: 205181.7433 | Val Loss: 3.1257
# Epoch 487 | Train Loss: 81518.1758 | Val Loss: 3.0980
# Epoch 488 | Train Loss: 191873.6982 | Val Loss: 3.0998
# Epoch 489 | Train Loss: 146166.8137 | Val Loss: 3.0911
# Epoch 490 | Train Loss: 222798.6388 | Val Loss: 3.1265
# Epoch 491 | Train Loss: 98741.9344 | Val Loss: 3.0956
# Epoch 492 | Train Loss: 105109.1196 | Val Loss: 3.1021
# Epoch 493 | Train Loss: 92653.7269 | Val Loss: 3.0552
# Epoch 494 | Train Loss: 91954.2129 | Val Loss: 3.0557
# Epoch 495 | Train Loss: 96993.6485 | Val Loss: 3.0603
# Epoch 496 | Train Loss: 87049.5575 | Val Loss: 3.0423
# Epoch 497 | Train Loss: 105829.1223 | Val Loss: 3.0216
# Epoch 498 | Train Loss: 106754.3920 | Val Loss: 3.0074
# Epoch 499 | Train Loss: 143091.6702 | Val Loss: 3.0503
# Epoch 500 | Train Loss: 69714.2253 | Val Loss: 3.1460
# Epoch 501 | Train Loss: 71621.9744 | Val Loss: 3.1332
# Epoch 502 | Train Loss: 66146.3128 | Val Loss: 3.1112
# Epoch 503 | Train Loss: 69328.0505 | Val Loss: 3.0796
# Epoch 504 | Train Loss: 71484.1319 | Val Loss: 3.0402
# Epoch 505 | Train Loss: 171627.5810 | Val Loss: 2.9920
# Epoch 506 | Train Loss: 144103.3106 | Val Loss: 2.9661
# Epoch 507 | Train Loss: 157943.6032 | Val Loss: 2.9448
# Epoch 508 | Train Loss: 73546.1769 | Val Loss: 2.9689
# Epoch 509 | Train Loss: 130793.4609 | Val Loss: 3.0054
# Epoch 510 | Train Loss: 128372.7559 | Val Loss: 2.9993
# Epoch 511 | Train Loss: 102704.2459 | Val Loss: 2.9904
# Epoch 512 | Train Loss: 53697.4695 | Val Loss: 3.0031
# Epoch 513 | Train Loss: 54830.8762 | Val Loss: 3.0293
# Epoch 514 | Train Loss: 62757.2600 | Val Loss: 3.0157
# Epoch 515 | Train Loss: 105563.2196 | Val Loss: 3.0193
# Epoch 516 | Train Loss: 92955.4519 | Val Loss: 3.2268
# Epoch 517 | Train Loss: 66920.9223 | Val Loss: 3.4522
# Epoch 518 | Train Loss: 59582.5333 | Val Loss: 3.4627
# Epoch 519 | Train Loss: 90047.3623 | Val Loss: 3.4430
# Epoch 520 | Train Loss: 104971.6911 | Val Loss: 3.4109
# Epoch 521 | Train Loss: 44833.8077 | Val Loss: 3.3826
# Epoch 522 | Train Loss: 121189.5133 | Val Loss: 3.3578
# Epoch 523 | Train Loss: 42044.1553 | Val Loss: 3.3386
# Epoch 524 | Train Loss: 72573.8661 | Val Loss: 3.3253
# Epoch 525 | Train Loss: 42920.5181 | Val Loss: 3.2190
# Epoch 526 | Train Loss: 46102.3501 | Val Loss: 3.1699
# Epoch 527 | Train Loss: 40964.0106 | Val Loss: 3.2307
# Epoch 528 | Train Loss: 46869.8912 | Val Loss: 3.2497
# Epoch 529 | Train Loss: 77832.6328 | Val Loss: 3.2546
# Epoch 530 | Train Loss: 39419.4942 | Val Loss: 3.1989
# Epoch 531 | Train Loss: 98090.4329 | Val Loss: 3.0570
# Epoch 532 | Train Loss: 85003.4852 | Val Loss: 2.9939
# Epoch 533 | Train Loss: 49592.6992 | Val Loss: 2.9733
# Epoch 534 | Train Loss: 49532.1327 | Val Loss: 2.8905
# Epoch 535 | Train Loss: 37657.5167 | Val Loss: 2.8171
# Epoch 536 | Train Loss: 81034.6757 | Val Loss: 2.8019
# Epoch 537 | Train Loss: 48025.0964 | Val Loss: 2.7812
# Epoch 538 | Train Loss: 44356.7484 | Val Loss: 2.6539
# Epoch 539 | Train Loss: 80075.2989 | Val Loss: 2.6305
# Epoch 540 | Train Loss: 73507.0051 | Val Loss: 2.6245
# Epoch 541 | Train Loss: 53192.1107 | Val Loss: 2.6094
# Epoch 542 | Train Loss: 55302.5721 | Val Loss: 2.5472
# Epoch 543 | Train Loss: 71234.8337 | Val Loss: 2.5674
# Epoch 544 | Train Loss: 74786.2631 | Val Loss: 2.5508
# Epoch 545 | Train Loss: 47491.8091 | Val Loss: 2.5324
# Epoch 546 | Train Loss: 59787.4033 | Val Loss: 2.5418
# Epoch 547 | Train Loss: 42902.4322 | Val Loss: 2.4202
# Epoch 548 | Train Loss: 29086.0782 | Val Loss: 2.3655
# Epoch 549 | Train Loss: 64267.9783 | Val Loss: 2.2877
# Epoch 550 | Train Loss: 49616.3427 | Val Loss: 2.1344
# Epoch 551 | Train Loss: 64364.0867 | Val Loss: 2.0987
# Epoch 552 | Train Loss: 26481.4243 | Val Loss: 2.0774
# Epoch 553 | Train Loss: 58269.3908 | Val Loss: 2.0459
# Epoch 554 | Train Loss: 34874.5283 | Val Loss: 2.0337
# Epoch 555 | Train Loss: 27232.1098 | Val Loss: 2.0246
# Epoch 556 | Train Loss: 56905.9363 | Val Loss: 2.0116
# Epoch 557 | Train Loss: 30159.4661 | Val Loss: 1.9982
# Epoch 558 | Train Loss: 48567.1379 | Val Loss: 1.9819
# Epoch 559 | Train Loss: 62761.4890 | Val Loss: 1.9598
# Epoch 560 | Train Loss: 24026.6333 | Val Loss: 1.9469
# Epoch 561 | Train Loss: 19238.6037 | Val Loss: 1.9357
# Epoch 562 | Train Loss: 21455.9617 | Val Loss: 1.9731
# Epoch 563 | Train Loss: 39471.5430 | Val Loss: 1.9953
# Epoch 564 | Train Loss: 16651.5745 | Val Loss: 1.9883
# Epoch 565 | Train Loss: 17914.8813 | Val Loss: 1.9895
# Epoch 566 | Train Loss: 19931.7873 | Val Loss: 2.1038
# Epoch 567 | Train Loss: 17041.0074 | Val Loss: 2.1454
# Epoch 568 | Train Loss: 23474.3534 | Val Loss: 2.1377
# Epoch 569 | Train Loss: 24675.5991 | Val Loss: 2.0715
# Epoch 570 | Train Loss: 29445.3024 | Val Loss: 2.0537
# Epoch 571 | Train Loss: 18158.6095 | Val Loss: 2.1161
# Epoch 572 | Train Loss: 43475.3783 | Val Loss: 2.1956
# Epoch 573 | Train Loss: 23243.9511 | Val Loss: 2.2108
# Epoch 574 | Train Loss: 44847.1269 | Val Loss: 2.1986
# Epoch 575 | Train Loss: 24829.1580 | Val Loss: 2.1045
# Epoch 576 | Train Loss: 17387.5328 | Val Loss: 2.0910
# Epoch 577 | Train Loss: 18791.5538 | Val Loss: 2.0566
# Epoch 578 | Train Loss: 41308.9885 | Val Loss: 1.9533
# Epoch 579 | Train Loss: 18642.3003 | Val Loss: 1.9202
# Epoch 580 | Train Loss: 30854.3109 | Val Loss: 1.9071
# Epoch 581 | Train Loss: 14843.1906 | Val Loss: 1.8966
# Epoch 582 | Train Loss: 20227.2383 | Val Loss: 1.8878
# Epoch 583 | Train Loss: 20774.9501 | Val Loss: 1.8777
# Epoch 584 | Train Loss: 19299.4972 | Val Loss: 1.8636
# Epoch 585 | Train Loss: 20962.2021 | Val Loss: 1.8517
# Epoch 586 | Train Loss: 15905.3112 | Val Loss: 1.8444
# Epoch 587 | Train Loss: 28812.1435 | Val Loss: 1.8402
# Epoch 588 | Train Loss: 13528.0259 | Val Loss: 1.8287
# Epoch 589 | Train Loss: 30260.8733 | Val Loss: 1.7489
# Epoch 590 | Train Loss: 26530.1892 | Val Loss: 1.7016
# Epoch 591 | Train Loss: 24350.9220 | Val Loss: 1.7049
# Epoch 592 | Train Loss: 16013.7166 | Val Loss: 1.5700
# Epoch 593 | Train Loss: 11288.7742 | Val Loss: 1.5238
# Epoch 594 | Train Loss: 15081.6382 | Val Loss: 1.4590
# Epoch 595 | Train Loss: 17172.8072 | Val Loss: 1.4516
# Epoch 596 | Train Loss: 23451.2419 | Val Loss: 1.4411
# Epoch 597 | Train Loss: 14799.4180 | Val Loss: 1.4276
# Epoch 598 | Train Loss: 13140.1069 | Val Loss: 2.1886
# Epoch 599 | Train Loss: 13782.9325 | Val Loss: 2.7241
# Epoch 600 | Train Loss: 24608.8221 | Val Loss: 2.8575
# Epoch 601 | Train Loss: 18320.4257 | Val Loss: 2.9221
# Epoch 602 | Train Loss: 10745.2508 | Val Loss: 2.9262
# Epoch 603 | Train Loss: 11750.3730 | Val Loss: 2.9100
# Epoch 604 | Train Loss: 11667.4381 | Val Loss: 2.9068
# Epoch 605 | Train Loss: 14252.1393 | Val Loss: 2.8781
# Epoch 606 | Train Loss: 7505.5818 | Val Loss: 2.8546
# Epoch 607 | Train Loss: 19646.6958 | Val Loss: 2.8483
# Epoch 608 | Train Loss: 18414.5315 | Val Loss: 2.8363
# Epoch 609 | Train Loss: 15058.0322 | Val Loss: 2.8360
# Epoch 610 | Train Loss: 9348.1784 | Val Loss: 2.8494
# Epoch 611 | Train Loss: 15465.2401 | Val Loss: 2.7307
# Epoch 612 | Train Loss: 6790.3662 | Val Loss: 2.6303
# Epoch 613 | Train Loss: 10360.0625 | Val Loss: 2.5864
# Epoch 614 | Train Loss: 10539.9702 | Val Loss: 2.6502
# Epoch 615 | Train Loss: 18119.5167 | Val Loss: 2.5720
# Epoch 616 | Train Loss: 22969.4362 | Val Loss: 2.5752
# Epoch 617 | Train Loss: 15027.0775 | Val Loss: 2.5352
# Epoch 618 | Train Loss: 15764.0188 | Val Loss: 2.4741
# Epoch 619 | Train Loss: 9506.9379 | Val Loss: 2.3085
# Epoch 620 | Train Loss: 7299.9901 | Val Loss: 2.3105
# Epoch 621 | Train Loss: 9045.7312 | Val Loss: 2.1634
# Epoch 622 | Train Loss: 6050.7326 | Val Loss: 2.0244
# Epoch 623 | Train Loss: 6866.9444 | Val Loss: 1.8439
# Epoch 624 | Train Loss: 5627.5519 | Val Loss: 1.7707
# Epoch 625 | Train Loss: 10657.3120 | Val Loss: 1.7228
# Epoch 626 | Train Loss: 5897.8370 | Val Loss: 1.7084
# Epoch 627 | Train Loss: 13630.6537 | Val Loss: 1.6931
# Epoch 628 | Train Loss: 7948.6005 | Val Loss: 1.6926
# Epoch 629 | Train Loss: 7194.6293 | Val Loss: 1.6971
# Epoch 630 | Train Loss: 13500.6689 | Val Loss: 1.6535
# Epoch 631 | Train Loss: 7301.6421 | Val Loss: 1.6381
# Epoch 632 | Train Loss: 8224.4698 | Val Loss: 1.6033
# Epoch 633 | Train Loss: 5395.4293 | Val Loss: 1.5886
# Epoch 634 | Train Loss: 11240.7538 | Val Loss: 1.5318
# Epoch 635 | Train Loss: 6111.1191 | Val Loss: 1.5253
# Epoch 636 | Train Loss: 5415.3614 | Val Loss: 1.5213
# Epoch 637 | Train Loss: 6329.5397 | Val Loss: 1.5163
# Epoch 638 | Train Loss: 8606.2946 | Val Loss: 1.5104
# Epoch 639 | Train Loss: 4888.8975 | Val Loss: 1.5080
# Epoch 640 | Train Loss: 4616.1316 | Val Loss: 1.5005
# Epoch 641 | Train Loss: 3914.7877 | Val Loss: 1.4896
# Epoch 642 | Train Loss: 3846.4415 | Val Loss: 1.4997
# Epoch 643 | Train Loss: 9216.9133 | Val Loss: 1.4638
# Epoch 644 | Train Loss: 3873.1701 | Val Loss: 1.4634
# Epoch 645 | Train Loss: 7677.0507 | Val Loss: 1.5023
# Epoch 646 | Train Loss: 3175.9058 | Val Loss: 1.7763
# Epoch 647 | Train Loss: 5316.6696 | Val Loss: 1.7813
# Early stopping triggered at epoch 647

# %% [markdown]
# ## Charger le modèle

# %%
# Charger le meilleur modèle
model.load_state_dict(torch.load("best_vgae_rgcn.pt"))
# Out:
# /tmp/ipykernel_65561/2582525375.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_vgae_rgcn.pt"))
# <All keys matched successfully>

# %% [markdown]
# ## Score de reconstruction

# %%
def edge_recon_error(z, edge_index):
    src, dst = edge_index
    logits = (z[src] * z[dst]).sum(dim=1)
    probs = torch.sigmoid(logits)
    error = -torch.log(probs + 1e-9)
    return error  # [num_edges]

# %% [markdown]
# ## Agrégation vers les NŒUDS

# %%
def node_anomaly_score(z, edge_index, num_nodes):
    edge_error = edge_recon_error(z, edge_index)

    src, dst = edge_index
    node_score = torch.zeros(num_nodes, device=z.device)
    node_score.scatter_add_(0, src, edge_error)
    node_score.scatter_add_(0, dst, edge_error)

    degree = torch.zeros(num_nodes, device=z.device)
    degree.scatter_add_(0, src, torch.ones_like(edge_error))
    degree.scatter_add_(0, dst, torch.ones_like(edge_error))

    return node_score / (degree + 1e-6)

# %% [markdown]
# ## Collecte sur les données de valisation

# %%
val_scores = []
val_labels = []

model.eval()
with torch.no_grad():
    for data in test_loader:
        data = data.to(device)

        z = model.encode(
            data.x,
            data.edge_index,
            data.edge_type
        )

        scores = node_anomaly_score(
            z,
            data.edge_index,
            data.num_nodes
        )

        print("data.y:", data.y)
        print("scores:", scores.shape)

        val_scores.extend(scores.cpu().numpy())
        val_labels.extend(data.y.cpu().numpy())
# Out:
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([30058])
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([85848])
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([88759])
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([69533])
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([69348])
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([72635])
# data.y: tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0')
# scores: torch.Size([139538])

# %% [markdown]
# ## Choisir un seuil

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(val_labels, val_scores)

# Exemple : maximiser F1
f1 = 2 * precision * recall / (precision + recall + 1e-9)
best_idx = np.argmax(f1)

best_threshold = thresholds[best_idx]
print("Best threshold:", best_threshold)
print("Precision:", precision[best_idx])
print("Recall:", recall[best_idx])
# Out:
# Best threshold: 13.81551
# Precision: 0.030921459492888066
# Recall: 0.023310023310023312

# %%
threshold = best_threshold # np.percentile(val_scores, 99)

# %% [markdown]
# ## TEST

# %%
test_scores = []
test_labels = []
test_preds  = []

with torch.no_grad():
    for data in test_loader:
        data = data.to(device)

        z = model.encode(
            data.x,
            data.edge_index,
            data.edge_type
        )

        scores = node_anomaly_score(
            z,
            data.edge_index,
            data.num_nodes
        )

        preds = (scores > threshold).long()

        test_scores.extend(scores.cpu().numpy())
        test_labels.extend(data.y.cpu().numpy())
        test_preds.extend(preds.cpu().numpy())

# %% [markdown]
# ## Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(test_labels, test_preds)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Normal", "Fraude"]
)
disp.plot()
